# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import json
from decouple import config
from urllib import request
import csv 
import datetime
import smtplib
from pandas import json_normalize

# f = open('/Users/dreamscape08/Desktop/Osteostrong Project/OSPGRM_files/DTC/DTC-users.json')
# DTC_data = json.load(f)

DTC_username = config('DTC_username')
DTC_password = config('DTC_password')

DTC_payload = {'username': DTC_username, 'password': DTC_password}
loginurl = ('https://osteostrong.org/auth')
DTC_totals = []

with requests.session() as DTC_s:
    DTC_s.post(loginurl, data=DTC_payload)
    DTC_url = f"https://osteostrong.org/user/users?LocationId=00093"
    DTC_r = DTC_s.get(DTC_url).text
    jsondata=json.loads(DTC_r)    
    df=pd.json_normalize(jsondata)
    allusersdtc=df[['FirstName.S', 'LastName.S', 'Email.S', 'Phone.S','UserId.S','NfcId.S']]#.to_csv('/Users/dreamscape08/Desktop/Osteostrong Project/OSPGRM_files/DTC/DTC-users.csv')
    for x in allusersdtc.index:
        usrid=allusersdtc.loc[x,'UserId.S']
        DTC_url = f"https://osteostrong.org/chart?UserId={usrid}&LocationId=00093"
        DTC_r = DTC_s.get(DTC_url)
        DTC_soup = BeautifulSoup(DTC_r.content, 'html.parser')
        DTC_total_sesh = DTC_soup.find_all('div', attrs={'class': 'col-1'})
        DTC_Total_Sessions = (DTC_total_sesh[2].text.strip())
        DTC_sesh_totals = int(DTC_Total_Sessions)
        # DTC_names = DTC_soup.find_all('div', attrs={'class': 'col-2'})
        # DTC_name = DTC_names[2].text.strip()[20:]
        DTC_totals.append([DTC_sesh_totals, usrid])
DTC_s.close()
# for i in jsondata:

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import json
from decouple import config
from sqlalchemy import create_engine
from urllib import request
import csv 
import datetime
import smtplib
from pandas import json_normalize
def dateme():
    parser = datetime.datetime.now()
    return parser.strftime("%m-%d-%Y")

# %%
# url="https://acuityscheduling.com/api/v1/clients?"
url = "https://acuityscheduling.com/api/v1/appointments?max=10000&minDate=2021-10-20&maxDate=2022-2-20&canceled=false&excludeForms=true&direction=ASC"

payload={}
headers = {
  'Authorization': 'Basic MTU3MTA3MTA6YTcxYzUyNjkwYjU1Yjk4NTVjMmJlMWNlNzc4MTIyZTI=',
  'Cookie': '; PHPSESSID=8sqcu1hijeqfo83ja1qi83am19; device_id=f8a738b4-38fd-426f-b163-c3f6fb346124'
}

response = requests.request("GET", url, headers=headers, data=payload).text


aquityjsondumps=json.loads(response)
df=pd.json_normalize(aquityjsondumps)

# %%
df
# Out:
#              id firstName   lastName       phone  \
# 0     461722889  Kristine      Kraft  3033199219
# 1     689035840    Millie      Cline  3038849940
# 2     592531309      Lori    Schultz  7203144563
# 3     505330187     Penny       Rice  4792161796
# 4     571822204      Ally   Macredie  7208386776
# ...         ...       ...        ...         ...
# 5558    459 South Vance St Lakewood, CO 80226        America/Denver
# 5559    459 South Vance St Lakewood, CO 80226        America/Denver
# 5560  7300 E Arapahoe Rd Centennial, CO 80112        America/Denver
# 5561    459 South Vance St Lakewood, CO 80226        America/Denver
#
#      calendarTimezone canceled  canClientCancel canClientReschedule  \
# 0      America/Denver    False            False               False
# 1      America/Denver    False            False               False
# 2      America/Denver    False            False               False
# 3      America/Denver    False            False               False
# 4      America/Denver    False            False               False
# ...               ...      ...              ...                 ...
# 5557   America/Denver    False            False                True
# 5558   America/Denver    False            False                True
# 5559   America/Denver    False            False                True
# 5560   America/Denver    False            False                True
# 5561   America/Denver    False            False                True
#
#                                                  labels subCalendarID
# 0                                                  None           NaN
# 1                                                  None           NaN
# 2                                                  None           NaN
# 3                                                  None           NaN
# 4     [{'id': 5139093, 'name': '50th - DXA*', 'color...           NaN
# ...                                                 ...           ...
# 5557                                               None           NaN
# 5558                                               None           NaN
# 5559                                               None           NaN
# 5560  [{'id': 3970910, 'name': 'DXA Baseline', 'colo...           NaN
# 5561                                               None           NaN
#
# [5562 rows x 34 columns]

# %%
# df=pd.read_json(response)
aquity_appointment_ids=pd.DataFrame(df,columns=['id', 'firstName','lastName', 'phone', 'email', 'date', 'time',
       'endTime', 'type', 'appointmentTypeID',
       'addonIDs', 'category', 'duration', 'calendar', 'calendarID',
       'confirmationPage'] )

# %%
aquity_appointment_ids.to_excel(f'/Users/dreamscape08/Desktop/Osteostrong Project/OS_Operations/DTC_aquitydb_{dateme()}.xlsx', header=True)
aquity_appointment_ids.to_excel(f'/Users/dreamscape08/Desktop/Osteostrong Project/OS_Operations/DTC_aquitydb_{dateme()}.xlsx', header=True)

# %%
aquity_appointment_ids
# Out:
#              id firstName   lastName       phone  \
# 0     461722889  Kristine      Kraft  3033199219
# 1     689035840    Millie      Cline  3038849940
# 2     592531309      Lori    Schultz  7203144563
# 3     505330187     Penny       Rice  4792161796
# 4     571822204      Ally   Macredie  7208386776
# ...         ...       ...        ...         ...
# 5557  745959482     Cindy    Perlman  4804958457
# 5558  748640062     Karen  Lightfoot  3039611880
# 5559  622764484     Susan       Mann  3035234228
# 5560  742551179       Rey      Vidal  7202780888
# 5561  748698251    Sherri      Teter  3039410450
#
#                                email              date    time endTime  \
# 0             kris.l.kraft@gmail.com  October 20, 2021  8:15am  8:30am
# 1              denvercline@yahoo.com  October 20, 2021  8:15am  8:30am
# 2           lorikschultz@comcast.net  October 20, 2021  8:30am  8:45am
# 3                   hte70295@aol.com  October 20, 2021  8:45am  9:00am
# 4             allymacredie@gmail.com  October 20, 2021  9:00am  9:30am
# ...                              ...               ...     ...     ...
# 5557              cjperl11@gmail.com  January 20, 2022  5:30pm  5:45pm
# 5558  karen.lightfoot@cloudsaway.com  January 20, 2022  5:30pm  5:45pm
# 5559                smannedm@aol.com  January 20, 2022  5:45pm  6:00pm
# 5560             reyvidal@icloud.com  January 20, 2022  5:45pm  6:00pm
# 5561          sherri.teter@gmail.com  January 20, 2022  5:45pm  6:00pm
#
#                                                    type  appointmentTypeID  \
# 0                       OsteoStrong Member + (Lakewood)           15355578
# 1                       OsteoStrong Member + (Lakewood)           15355578
# 2              OsteoStrong session (members) - Lakewood            6532246
# 3                       OsteoStrong Member + (Lakewood)           15355578
# 4     OsteoStrong Session - 4th baseline (50th session)           12210876
# ...                                                 ...                ...
# 5557           OsteoStrong session (members) - Lakewood            6532246
# 5558                    OsteoStrong Member + (Lakewood)           15355578
# 5559           OsteoStrong session (members) - Lakewood            6532246
# 5560                OsteoStrong session (members) - DTC           11974033
# 5561           OsteoStrong session (members) - Lakewood            6532246
#
#      addonIDs         category duration                        calendar  \
# 0          []  2) Members Only       15  OsteoStrong Lakewood - Members
# 1          []  2) Members Only       15  OsteoStrong Lakewood - Members
# 2          []  2) Members Only       15  OsteoStrong Lakewood - Members
# 3          []  2) Members Only       15  OsteoStrong Lakewood - Members
# 4          []  2) Members Only       30  OsteoStrong Lakewood - Members
# ...       ...              ...      ...                             ...
# 5557       []  2) Members Only       15  OsteoStrong Lakewood - Members
# 5558       []  2) Members Only       15  OsteoStrong Lakewood - Members
# 5559       []  2) Members Only       15  OsteoStrong Lakewood - Members
# 5560       []  2) Members Only       15       OsteoStrong DTC - Members
# 5561       []  2) Members Only       15  OsteoStrong Lakewood - Members
#
#       calendarID                                   confirmationPage
# 0        2179752  https://app.acuityscheduling.com/schedule.php?...
# 1        2179752  https://app.acuityscheduling.com/schedule.php?...
# 2        2179752  https://app.acuityscheduling.com/schedule.php?...
# 3        2179752  https://app.acuityscheduling.com/schedule.php?...
# 4        2179752  https://app.acuityscheduling.com/schedule.php?...
# ...          ...                                                ...
# 5557     2179752  https://app.acuityscheduling.com/schedule.php?...
# 5558     2179752  https://app.acuityscheduling.com/schedule.php?...
# 5559     2179752  https://app.acuityscheduling.com/schedule.php?...
# 5560     3179100  https://app.acuityscheduling.com/schedule.php?...
# 5561     2179752  https://app.acuityscheduling.com/schedule.php?...
#
# [5562 rows x 16 columns]

# %%
username = config('pg_username')
password = config('pg_password')

host = 'localhost'
port = '5432'
database = 'aquity'
postgres_str = f'postgresql://{username}:{password}@{host}:{port}/{database}'
cnx=create_engine(postgres_str)

aquity_appointment_ids.to_sql('aquity_clientdb', cnx, if_exists='replace' ,index=False)
