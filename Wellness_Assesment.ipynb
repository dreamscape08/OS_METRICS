# %%
from typeform import Typeform
typeform=Typeform('tfp_49PmKxQpBFZHNWJ1ipoVcFTVyhRiMZuqetwnpVD4W8Pt_e4CT4nD3175N')
import requests

# %%
r=requests.get('https://api.typeform.com/forms/xwaNlc',headers={'key':'tfp_49PmKxQpBFZHNWJ1ipoVcFTVyhRiMZuqetwnpVD4W8Pt_e4CT4nD3175N'})

# %%
r.close()

# %%
r=requests.get('https://api.typeform.com/forms/xwaNlc/responses',headers={'key':'49PmKxQpBFZHNWJ1ipoVcFTVyhRiMZuqetwnpVD4W8Pt_e4CT4nD3175N'})

# %%
form_id='xwaNlc'

# %%
r.json()
# Out:
# {'id': 'xwaNlc',
#  'type': 'quiz',
#  'title': 'OsteoStrong Wellness Assessment (DTC)',
#  'workspace': {'href': 'https://api.typeform.com/workspaces/3dmS9z'},
#  'theme': {'href': 'https://api.typeform.com/themes/xpM492'},
#  'settings': {'language': 'en',
#   'progress_bar': 'percentage',
#   'meta': {'allow_indexing': True},
#   'hide_navigation': False,
#   'is_public': True,
#   'is_trial': False,
#   'show_progress_bar': True,
#   'show_typeform_branding': True,
#   'are_uploads_public': False,
#   'show_time_to_complete': True,
#   'redirect_after_submit_url': 'https://try.osteostrong.me/thank-you/',
#   'pro_subdomain_enabled': False,
#   'capabilities': {'e2e_encryption': {'enabled': False, 'modifiable': False}}},
#  'thankyou_screens': [{'id': 'YTqhCfjVk0la',
#    'ref': '13e4',
# ...

# %%
https://api.typeform.com/forms/{form_id}/responses
# Out:
#   File "<ipython-input-42-d1ed49ddabf1>", line 1
#     https://api.typeform.com/forms/{form_id}/responses
#           ^
# SyntaxError: invalid syntax

# %%
def addition(x, y):
    return x + y
 
numbers1 = [5, 6, 2, 8]
numbers2 = [7, 1, 4, 9]
result = map(addition, numbers1, numbers2)
print(list(result))
